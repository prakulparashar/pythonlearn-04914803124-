# %%
import job_analyser #or-> from job_analyser import calculate_salary... then no need of job_analyser. OR-> from job_analyser import * (imports all fxns)

job_analyser.calculate_salary(100000,0.1)
# Out:
# 110000.00000000001
